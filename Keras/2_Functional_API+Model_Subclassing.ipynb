# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential,layers
from tensorflow.keras.datasets import mnist

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train=x_train.reshape(-1,28*28)/255.0
x_test=x_test.reshape(-1,28*28)/255.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.25,random_state=42)

# %%
#Functional API
inputs=keras.Input(shape=(784,))
x=layers.Dense(512,activation='relu',name='first_hidden_layer')(inputs)
x=layers.Dense(256,activation='relu',name='second_hidden_layer')(x)
outputs=layers.Dense(10,activation='softmax',name='output_layer')(x)
model=keras.Model(inputs=inputs,outputs=outputs)

# %%
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(),
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5,verbose=2,batch_size=64,validation_data=(x_val,y_val))
# Out:
# Epoch 1/5
# 704/704 - 5s - 8ms/step - accuracy: 0.9334 - loss: 0.2265 - val_accuracy: 0.9637 - val_loss: 0.1221
# Epoch 2/5
# 704/704 - 2s - 3ms/step - accuracy: 0.9738 - loss: 0.0858 - val_accuracy: 0.9707 - val_loss: 0.0960
# Epoch 3/5
# 704/704 - 3s - 4ms/step - accuracy: 0.9817 - loss: 0.0568 - val_accuracy: 0.9727 - val_loss: 0.0924
# Epoch 4/5
# 704/704 - 2s - 3ms/step - accuracy: 0.9861 - loss: 0.0414 - val_accuracy: 0.9725 - val_loss: 0.0957
# Epoch 5/5
# 704/704 - 1s - 2ms/step - accuracy: 0.9896 - loss: 0.0318 - val_accuracy: 0.9716 - val_loss: 0.1128

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9727 - loss: 0.1022
# [0.09295549243688583, 0.9746999740600586]

# %%
#sub-classing
class MyModel(keras.Model):
  def __init__(self,num_classes=10):
    super(MyModel,self).__init__()
    self.dense1=layers.Dense(512,activation='relu')
    self.dense2=layers.Dense(256,activation='relu')
    self.dense3=layers.Dense(num_classes)
  def call(self,inputs):
    x=self.dense1(inputs)
    x=self.dense2(x)
    x=self.dense3(x)
    return x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fbdf9deb539a> in <cell line: 0>()
#       1 #sub-classing
# ----> 2 class MyModel(keras.Model):
#       3   def __init__(self,num_classes=10):
#       4     super(MyModel,self).__init__()
#       5     self.dense1=layers.Dense(512,activation='relu')
#
# NameError: name 'keras' is not defined

# %% [markdown]
# 1.   MyModel is a custom class that inherits from keras.Model, allowing you to define your own layers and forward pass logic.
#
# 2. The __init__ method initializes the model's layers and other components.
# 3. super(MyModel, self).__init__():Calls the constructor of the parent class (keras.Model) to initialize inherited functionality.

# %%
model1=MyModel()

# %%
model1.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])

# %%
model1.fit(x_train,y_train,epochs=5,verbose=2,batch_size=64,validation_data=(x_val,y_val))
# Out:
# Epoch 1/5
# 704/704 - 5s - 7ms/step - accuracy: 0.9323 - loss: 0.2275 - val_accuracy: 0.9591 - val_loss: 0.1366
# Epoch 2/5
# 704/704 - 3s - 5ms/step - accuracy: 0.9732 - loss: 0.0869 - val_accuracy: 0.9685 - val_loss: 0.0997
# Epoch 3/5
# 704/704 - 1s - 2ms/step - accuracy: 0.9823 - loss: 0.0548 - val_accuracy: 0.9669 - val_loss: 0.1098
# Epoch 4/5
# 704/704 - 3s - 4ms/step - accuracy: 0.9859 - loss: 0.0418 - val_accuracy: 0.9693 - val_loss: 0.1093
# Epoch 5/5
# 704/704 - 1s - 2ms/step - accuracy: 0.9901 - loss: 0.0309 - val_accuracy: 0.9783 - val_loss: 0.0814

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9781 - loss: 0.0743
# [0.06501521170139313, 0.9814000129699707]
