# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential,layers,regularizers
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,BatchNormalization,Dropout
from tensorflow.keras.datasets import cifar10

# %%
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
x_train=x_train.astype('float32')/255.0
x_test=x_test.astype('float32')/255.0

# %%
from sklearn.model_selection import train_test_split
x_train,x_val,y_train,y_val=train_test_split(x_train,y_train,test_size=0.2,random_state=42)

# %%
model=Sequential(
    [
        keras.Input(shape=(32,32,3)),
        layers.Conv2D(32,3,activation='relu'),
        layers.MaxPool2D(2),
        layers.Conv2D(64,3,activation='relu'),
        layers.MaxPool2D(2),
        layers.Conv2D(128,3,activation='relu'),
        layers.MaxPool2D(2),
        layers.Flatten(),
        layers.Dense(64,activation='relu'),
        layers.Dense(10)
    ]
)

# %%
#Sequential
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',input_shape=(32,32,3)))
model.add(MaxPool2D(2))
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPool2D())
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(64,activation='relu'))
model.add(Dense(10,activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              optimizer=keras.optimizers.Adam(learning_rate=3e-4),
              metrics=['accuracy']
)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 4, 4, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 2, 2, 128)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 64)                  │          32,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 126,730 (495.04 KB)
#  Trainable params: 126,730 (495.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,batch_size=64,epochs=10,validation_data=(x_val,y_val),verbose=2)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/backend/tensorflow/nn.py:635: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 625/625 - 9s - 14ms/step - accuracy: 0.1617 - loss: 2.2126 - val_accuracy: 0.2260 - val_loss: 2.0974
# Epoch 2/10
# 625/625 - 7s - 11ms/step - accuracy: 0.2366 - loss: 2.0702 - val_accuracy: 0.2584 - val_loss: 2.0262
# Epoch 3/10
# 625/625 - 3s - 4ms/step - accuracy: 0.2683 - loss: 2.0083 - val_accuracy: 0.2848 - val_loss: 1.9781
# Epoch 4/10
# 625/625 - 5s - 8ms/step - accuracy: 0.2922 - loss: 1.9519 - val_accuracy: 0.3058 - val_loss: 1.9217
# Epoch 5/10
# 625/625 - 2s - 4ms/step - accuracy: 0.3139 - loss: 1.8949 - val_accuracy: 0.3252 - val_loss: 1.8668
# Epoch 6/10
# 625/625 - 3s - 4ms/step - accuracy: 0.3316 - loss: 1.8447 - val_accuracy: 0.3274 - val_loss: 1.8369
# Epoch 7/10
# 625/625 - 2s - 3ms/step - accuracy: 0.3388 - loss: 1.8135 - val_accuracy: 0.3400 - val_loss: 1.8109
# Epoch 8/10
# 625/625 - 2s - 3ms/step - accuracy: 0.3512 - loss: 1.7867 - val_accuracy: 0.3442 - val_loss: 1.7894
# Epoch 9/10
# 625/625 - 2s - 3ms/step - accuracy: 0.3570 - loss: 1.7704 - val_accuracy: 0.3508 - val_loss: 1.7709
# Epoch 10/10
# 625/625 - 2s - 3ms/step - accuracy: 0.3662 - loss: 1.7492 - val_accuracy: 0.3622 - val_loss: 1.7507

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3849 - loss: 1.7276
# [1.7364060878753662, 0.37310001254081726]

# %%
#functional API
inputs=keras.Input(shape=(32,32,3))
x=layers.Conv2D(32,3)(inputs)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Conv2D(64,3)(x)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Conv2D(128,3)(x)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Flatten()(x)
x=layers.Dense(64,activation='relu')(x)
outputs=layers.Dense(10,activation='softmax')(x)
model1=keras.Model(inputs=inputs,outputs=outputs)

# %%
model1.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer=keras.optimizers.Adam(learning_rate=3e-4),
              metrics=['accuracy']
)

# %%
model1.fit(x_train,y_train,batch_size=64,epochs=10,validation_data=(x_val,y_val),verbose=2)
# Out:
# Epoch 1/10
# 625/625 - 9s - 15ms/step - accuracy: 0.4885 - loss: 1.4405 - val_accuracy: 0.1040 - val_loss: 4.6607
# Epoch 2/10
# 625/625 - 2s - 3ms/step - accuracy: 0.6237 - loss: 1.0706 - val_accuracy: 0.1040 - val_loss: 19.0778
# Epoch 3/10
# 625/625 - 2s - 3ms/step - accuracy: 0.6822 - loss: 0.9179 - val_accuracy: 0.0974 - val_loss: 7.9303
# Epoch 4/10
# 625/625 - 3s - 4ms/step - accuracy: 0.7214 - loss: 0.8118 - val_accuracy: 0.1072 - val_loss: 13.5360
# Epoch 5/10
# 625/625 - 2s - 4ms/step - accuracy: 0.7491 - loss: 0.7293 - val_accuracy: 0.1135 - val_loss: 10.8370
# Epoch 6/10
# 625/625 - 2s - 4ms/step - accuracy: 0.7745 - loss: 0.6567 - val_accuracy: 0.1041 - val_loss: 34.2371
# Epoch 7/10
# 625/625 - 3s - 4ms/step - accuracy: 0.7987 - loss: 0.5917 - val_accuracy: 0.0989 - val_loss: 14.8015
# Epoch 8/10
# 625/625 - 2s - 3ms/step - accuracy: 0.8172 - loss: 0.5319 - val_accuracy: 0.1040 - val_loss: 19.4703
# Epoch 9/10
# 625/625 - 3s - 4ms/step - accuracy: 0.8397 - loss: 0.4760 - val_accuracy: 0.0974 - val_loss: 24.0627
# Epoch 10/10
# 625/625 - 5s - 8ms/step - accuracy: 0.8569 - loss: 0.4270 - val_accuracy: 0.1134 - val_loss: 29.3594

# %%
model1.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1114 - loss: 29.3207
# [29.336740493774414, 0.11349999904632568]

# %%
inputs=keras.Input(shape=(32,32,3))
x=layers.Conv2D(32,3,kernel_regularizer=regularizers.l2(0.01))(inputs)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Conv2D(64,3,kernel_regularizer=regularizers.l2(0.01))(x)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Conv2D(128,3,kernel_regularizer=regularizers.l2(0.01))(x)
x=layers.BatchNormalization()(x)
x=keras.activations.relu(x)
x=layers.MaxPool2D()(x)
x=layers.Flatten()(x)
x=layers.Dense(64,activation='relu')(x)
x=layers.Dropout(0.5)(x)
outputs=layers.Dense(10,activation='softmax')(x)
model2=keras.Model(inputs=inputs,outputs=outputs)

# %%
model2.compile(loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              optimizer=keras.optimizers.Adam(learning_rate=3e-4),
              metrics=['accuracy']
)

# %%
model2.fit(x_train,y_train,batch_size=64,epochs=10,validation_data=(x_val,y_val),verbose=2)
# Out:
# Epoch 1/10
# 625/625 - 9s - 15ms/step - accuracy: 0.3498 - loss: 2.8392 - val_accuracy: 0.1040 - val_loss: 5.4267
# Epoch 2/10
# 625/625 - 6s - 10ms/step - accuracy: 0.4952 - loss: 2.0382 - val_accuracy: 0.1503 - val_loss: 4.7927
# Epoch 3/10
# 625/625 - 2s - 4ms/step - accuracy: 0.5595 - loss: 1.6616 - val_accuracy: 0.0999 - val_loss: 10.0476
# Epoch 4/10
# 625/625 - 2s - 4ms/step - accuracy: 0.6020 - loss: 1.4458 - val_accuracy: 0.1040 - val_loss: 12.5916
# Epoch 5/10
# 625/625 - 3s - 4ms/step - accuracy: 0.6301 - loss: 1.3233 - val_accuracy: 0.1130 - val_loss: 3.0642
# Epoch 6/10
# 625/625 - 3s - 5ms/step - accuracy: 0.6532 - loss: 1.2317 - val_accuracy: 0.1171 - val_loss: 19.5508
# Epoch 7/10
# 625/625 - 4s - 7ms/step - accuracy: 0.6738 - loss: 1.1694 - val_accuracy: 0.1118 - val_loss: 16.7962
# Epoch 8/10
# 625/625 - 2s - 3ms/step - accuracy: 0.6851 - loss: 1.1232 - val_accuracy: 0.0979 - val_loss: 19.0466
# Epoch 9/10
# 625/625 - 2s - 4ms/step - accuracy: 0.6987 - loss: 1.0851 - val_accuracy: 0.1129 - val_loss: 10.4523
# Epoch 10/10
# 625/625 - 2s - 4ms/step - accuracy: 0.7138 - loss: 1.0462 - val_accuracy: 0.1120 - val_loss: 15.2975
